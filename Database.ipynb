# %%
import json
import requests

# %%
url = "https://kitsu.io/api/edge/anime"
 
response = requests.get(url)

print(response)
print(response.status_code)
# Out:
# <Response [200]>
# 200

# %%
response_json = response.json()

# %%
print(f"The first response is {json.dumps(response_json, indent=2)}.")
# Out:
# The first response is {
#   "data": [
#     {
#       "id": "1",
#       "type": "anime",
#       "links": {
#         "self": "https://kitsu.io/api/edge/anime/1"
#       },
#       "attributes": {
#         "createdAt": "2013-02-20T16:00:13.609Z",
#         "updatedAt": "2021-03-19T00:02:51.990Z",
#         "slug": "cowboy-bebop",
# ...
